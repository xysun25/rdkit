# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw

# %%
mol = Chem.MolFromSmiles('CNC(=O)C1=CC=CC=C1SC2=CC3=C(C=C2)C(=N[NH]3)\C=C\C4=CC=CC=N4')
fig = Draw.MolToImage(mol, size=(500, 500))
fig.save('./mols.png')

# %%
mol = Chem.MolFromSmiles('CNC(=O)C1=CC=CC=C1SC2=CC3=C(C=C2)C(=N[NH]3)\C=C\C4=CC=CC=N4')
Draw.MolToImage(mol, size=(500, 500))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500 at 0x15D0A773D48>

# %%
mol = Chem.MolFromSmiles('[nH]1cnc2cncnc21')
Draw.MolToImage(mol, size=(100, 100), kekulize=True,
                wedgeBonds=True, fitImage=False)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100 at 0x15D0A7826C8>

# %%
mol = Chem.MolFromSmiles('C1=C[N]C=C1')
Draw.MolToImage(mol, size=(100, 100), kekulize=True,
                wedgeBonds=True, fitImage=False)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100 at 0x15D0A782E08>

# %%
# 展示
Draw.ShowMol(mol, size=(300, 300), kekulize=True, 
             wedgeBonds=True, title='RDKit Molecule')

Draw.MolToMPL(mol, size=(100, 100), kekulize=True, 
             wedgeBonds=True)

# %%
# 读入sdf格式文件
mol_list = Chem.SDMolSupplier('FDA-approved-Drug-kinase-inhibitor75.sdf')
fig = Draw.MolsToGridImage(
    mol_list, 
    molsPerRow=4, 
    subImgSize=(500, 500)
)
fig.save('./mols.png')
# Out:
# H:\software\anaconda\lib\site-packages\rdkit\Chem\Draw\IPythonConsole.py:260: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   % (maxMols))
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-15-9fa52c4311cf> in <module>
#       4     mol_list,
#       5     molsPerRow=4,
# ----> 6     subImgSize=(500, 500)
#       7 )
#       8 fig.save('./mols.png')
#
# H:\software\anaconda\lib\site-packages\rdkit\Chem\Draw\IPythonConsole.py in ShowMols(mols, maxMols, **kwargs)
#     259       "Truncating the list of molecules to be displayed to %d. Change the maxMols value to display more."
#     260       % (maxMols))
# --> 261     mols = mols[:maxMols]
#     262     for prop in ('legends', 'highlightAtoms', 'highlightBonds'):
#     263       if prop in kwargs:
#
# ArgumentError: Python argument types in
#     SDMolSupplier.__getitem__(SDMolSupplier, slice)
# did not match C++ signature:
#     __getitem__(class RDKit::SDMolSupplier * __ptr64, int)
